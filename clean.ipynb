# %% [markdown]
# # NYC Data Cleaning
#
# * **DuckDB** is the safer default when you might hit very large data on very little memory.
# * **Polars** is fantastic for fast, expressive DataFrame work once the working set fits comfortably in RAM (or after you’ve trimmed it down).
#
# ### If you’re memory-constrained or the data is huge
#
# * **Pick: DuckDB.**
# * Why: disk-backed query engine, external (out-of-core) joins/groupbys, automatic spilling, great at reading many CSV/Parquet files and doing big merges without blowing RAM.
# * Bonus: SQL is stable/portable, easy to hand off or productionize.
#
# ### If you want the fastest in-memory analytics in Python
#
# * **Pick: Polars.**
# * Why: Rust engine, lazy execution, predicate pushdown, superb groupbys/window ops, very fast on a single machine.
# * Caveat: while Polars has streaming, not every operation is fully out-of-core; truly massive many-to-many joins still prefer DuckDB.
#
# ### A simple rule of thumb
#
# * **Joins-first, massive ETL, union lots of files, ad-hoc SQL → DuckDB.**
# * **Feature engineering, tidy transforms, complex expressions, post-aggregation work → Polars.**
#
# ### A solid “future-proof” workflow
#
# 1. **Stage & shrink with DuckDB** (read many raw files, filter, project, big joins, aggregate → write Parquet).
# 2. **Analyze with Polars** on the smaller Parquet outputs (fast iteration, modeling features, plotting).
#
# * If you want one tool to start with for “extremely large on very low memory,” choose **DuckDB**. Add **Polars** to your toolkit for everything after the heavy lifting.
# * If you dont want to use any of the above, in pandas limit the columns, remove any sorting operations, split the data month by month into parque files and merge one by one.

# %% [markdown]
# ## Install Libs

# %%
import sys, platform
print(sys.executable)
print(sys.version)
print(platform.platform())
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/bin/python
# 3.13.7 (main, Aug 14 2025, 11:12:11) [Clang 17.0.0 (clang-1700.0.13.3)]
# macOS-15.2-arm64-arm-64bit-Mach-O

# %%
# !pip install pandas
# !pip install numpy
# %pip install -U duckdb
# %pip install -U polars
# %pip install -U pyarrow
# (the %pip magic binds to the current kernel’s interpreter)
# Out:
# Requirement already satisfied: pandas in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /Users/harekrsna/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.3.4)
# Requirement already satisfied: duckdb in /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages (1.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: polars in /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages (1.34.0)
# Requirement already satisfied: polars-runtime-32==1.34.0 in /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages (from polars) (1.34.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages (22.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Libs

# %%
import pandas as pd
import numpy as np
import duckdb
import pyarrow
import polars as pl
from pathlib import Path

# %% [markdown]
# ## Import Data

# %%
# For csv use
# pl.scan_csv("data.csv", has_header=True)
df_trips = pl.scan_parquet("datasets/yellow_tripdata_2024-01.parquet")
df_zones = pl.scan_parquet("datasets/taxi_zone_lookup.parquet")
df_weather = pl.scan_parquet('datasets/weather_data.parquet')
display(df_trips.head(2).collect())
display(df_zones.head(2).collect())
display(df_weather.head(2).collect())
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ Airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2024-01-0 ┆ 2024-01-0 ┆ 1         ┆ … ┆ 1.0       ┆ 22.7      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:57:55  ┆ 01:17:43  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-01-0 ┆ 2024-01-0 ┆ 1         ┆ … ┆ 1.0       ┆ 18.75     ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:03:00  ┆ 00:09:36  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# shape: (2, 4)
# ┌────────────┬─────────┬────────────────┬──────────────┐
# │ LocationID ┆ Borough ┆ Zone           ┆ service_zone │
# │ ---        ┆ ---     ┆ ---            ┆ ---          │
# │ i64        ┆ str     ┆ str            ┆ str          │
# ╞════════════╪═════════╪════════════════╪══════════════╡
# │ 1          ┆ EWR     ┆ Newark Airport ┆ EWR          │
# │ 2          ┆ Queens  ┆ Jamaica Bay    ┆ Boro Zone    │
# └────────────┴─────────┴────────────────┴──────────────┘
# shape: (2, 26)
# ┌──────┬───────┬─────┬──────┬───┬──────┬─────────────┬──────┬─────────────┐
# │ year ┆ month ┆ day ┆ hour ┆ … ┆ cldc ┆ cldc_source ┆ coco ┆ coco_source │
# │ ---  ┆ ---   ┆ --- ┆ ---  ┆   ┆ ---  ┆ ---         ┆ ---  ┆ ---         │
# │ i64  ┆ i64   ┆ i64 ┆ i64  ┆   ┆ i64  ┆ str         ┆ i64  ┆ str         │
# ╞══════╪═══════╪═════╪══════╪═══╪══════╪═════════════╪══════╪═════════════╡
# │ 2024 ┆ 1     ┆ 1   ┆ 0    ┆ … ┆ 8    ┆ dwd_hourly  ┆ 8    ┆ dwd_hourly  │
# │ 2024 ┆ 1     ┆ 1   ┆ 1    ┆ … ┆ 8    ┆ dwd_hourly  ┆ 7    ┆ dwd_poi     │
# └──────┴───────┴─────┴──────┴───┴──────┴─────────────┴──────┴─────────────┘

# %%
df_trips = pd.DataFrame({})

# %% [markdown]
# ### DuckDB

# %%
def executeWithDuckdb():
    con = duckdb.connect()
    
    con.execute("""
    CREATE OR REPLACE TABLE trips_hour_zone AS
    SELECT
      date_trunc('hour', CAST(tpep_pickup_datetime AS TIMESTAMP)) AS hour_local,
      CAST(PULocationID AS INTEGER) AS PULocationID,
      COUNT(*) AS trips,
      AVG(fare_amount) AS avg_fare,
      AVG(tip_amount) AS avg_tip,
      AVG(total_amount) AS avg_total,
      AVG(trip_distance) AS avg_distance,
      SUM(tip_amount) / NULLIF(SUM(total_amount), 0) AS tip_pct,
      AVG(DATEDIFF('minute', CAST(tpep_pickup_datetime AS TIMESTAMP),
                             CAST(tpep_dropoff_datetime AS TIMESTAMP))) AS avg_trip_minutes
    FROM read_parquet('datasets/yellow_tripdata_2024-01.parquet')
    WHERE tpep_pickup_datetime IS NOT NULL AND PULocationID IS NOT NULL
    GROUP BY 1,2;
    """)
    
    con.execute("""
    CREATE OR REPLACE TABLE taxi_zone AS
    SELECT CAST(LocationID AS INTEGER) AS PULocationID, Borough, Zone, service_zone
    FROM read_parquet('datasets/taxi_zone_lookup.parquet');
    """)
    
    con.execute("""
    CREATE OR REPLACE TABLE weather AS
    SELECT
      make_timestamp(CAST(year AS INTEGER), CAST(month AS INTEGER),
                     CAST(day AS INTEGER), CAST(hour AS INTEGER), 0, 0) AS hour_local,
      CAST(temp AS DOUBLE) AS temp_c,
      CAST(rhum AS DOUBLE) AS humidity,
      CAST(prcp AS DOUBLE) AS precip_mm,
      CAST(wdir AS DOUBLE) AS wind_direction,
      CAST(wspd AS DOUBLE) AS wind_speed_kmh,
      CAST(pres AS DOUBLE) AS pressure_hpa,
      coco AS weather_condition
    FROM read_parquet('datasets/weather_data.parquet')
    WHERE year IS NOT NULL AND month IS NOT NULL AND day IS NOT NULL AND hour IS NOT NULL;
    """)
    
    df_trips = con.execute("""
    SELECT
      t.hour_local, t.PULocationID, z.Borough, z.Zone, z.service_zone,
      t.trips, t.avg_fare, t.avg_tip, t.avg_total, t.avg_distance, t.tip_pct, t.avg_trip_minutes,
      w.temp_c, w.humidity, w.precip_mm, w.wind_direction, w.wind_speed_kmh, w.pressure_hpa, w.weather_condition
    FROM trips_hour_zone t
    LEFT JOIN weather w USING (hour_local)
    LEFT JOIN taxi_zone z USING (PULocationID)
    ORDER BY t.hour_local, t.PULocationID;
    """).df() 
    # This gives Pandas df

    print("Executed by DuckDB")
    return df_trips

# %% [markdown]
# ### Polars (Alternative to DuckDB)

# %%
def executeWithPolars():
    trips = (
        pl.scan_parquet("datasets/yellow_tripdata_2024-01.parquet")
        .with_columns([
            pl.col("tpep_pickup_datetime")
              .dt.truncate("1h")
              .dt.cast_time_unit("us")             # <- unify to μs
              .alias("hour_local"),
            pl.col("PULocationID").cast(pl.Int32),
            pl.col("tpep_dropoff_datetime"),
        ])
        .with_columns([
            (pl.col("tpep_dropoff_datetime") - pl.col("tpep_pickup_datetime"))
              .dt.total_minutes()
              .alias("trip_minutes")
        ])
        .group_by(["hour_local", "PULocationID"])
        .agg([
            pl.len().alias("trips"),
            pl.col("fare_amount").mean().alias("avg_fare"),
            pl.col("tip_amount").mean().alias("avg_tip"),
            pl.col("total_amount").mean().alias("avg_total"),
            pl.col("trip_distance").mean().alias("avg_distance"),
            (pl.col("tip_amount").sum() / pl.col("total_amount").sum()).alias("tip_pct"),
            pl.col("trip_minutes").mean().alias("avg_trip_minutes"),
        ])
    )

    zones = (
        pl.scan_parquet("datasets/taxi_zone_lookup.parquet")
        .select([pl.col("LocationID").cast(pl.Int32).alias("PULocationID"), "Borough", "Zone", "service_zone"])
    )

    weather = (
        pl.scan_parquet("datasets/weather_data.parquet")
        .with_columns([
            pl.datetime(
                pl.col("year").cast(pl.Int32),
                pl.col("month").cast(pl.Int32),
                pl.col("day").cast(pl.Int32),
                pl.col("hour").cast(pl.Int32),
                time_unit="us"                      # <- build as μs
            ).alias("hour_local")
        ])
        .select([
            "hour_local",
            pl.col("temp").alias("temp_c"),
            pl.col("rhum").alias("humidity"),
            pl.col("prcp").alias("precip_mm"),
            pl.col("wdir").alias("wind_direction"),
            pl.col("wspd").alias("wind_speed_kmh"),
            pl.col("pres").alias("pressure_hpa"),
            pl.col("coco").alias("weather_condition"),
        ])
    )

    df_trips = (
        trips.join(weather, on="hour_local", how="left")
             .join(zones, on="PULocationID", how="left")
             .sort(["hour_local", "PULocationID"])
             .collect()
             .to_pandas()
    )

    print("Executed by Polars")
    return df_trips

# %% [markdown]
# ### Pandas (Alternative to Polars)

# %%
def executeWithPandas():
    base = Path("datasets")
    trips = pd.read_parquet(base / "yellow_tripdata_2024-01.parquet", dtype_backend="pyarrow")

    trips["PULocationID"] = trips["PULocationID"].astype("Int64")
    trips["hour_local"] = trips["tpep_pickup_datetime"].dt.floor("h")  # -> timestamp[us][pyarrow]
    trips["trip_minutes"] = (trips["tpep_dropoff_datetime"] - trips["tpep_pickup_datetime"]).dt.total_seconds()/60

    agg = (
        trips.groupby(["hour_local","PULocationID"], dropna=False)
        .agg(
            trips=("VendorID","size"),
            avg_fare=("fare_amount","mean"),
            avg_tip=("tip_amount","mean"),
            avg_total=("total_amount","mean"),
            avg_distance=("trip_distance","mean"),
            tip_sum=("tip_amount","sum"),
            total_sum=("total_amount","sum"),
            avg_trip_minutes=("trip_minutes","mean"),
        )
        .reset_index()
    )

    # vectorized, avoids apply
    agg["tip_pct"] = (agg["tip_sum"] / agg["total_sum"].where(agg["total_sum"].ne(0))).fillna(0.0)
    agg = agg.drop(columns=["tip_sum","total_sum"])

    zones = pd.read_parquet(base / "taxi_zone_lookup.parquet", dtype_backend="pyarrow").rename(columns={"LocationID":"PULocationID"})
    zones["PULocationID"] = pd.to_numeric(zones["PULocationID"], errors="coerce").astype("Int64")

    weather = pd.read_parquet(base / "weather_data.parquet", dtype_backend="pyarrow")
    for c in ["year","month","day","hour"]:
        weather[c] = pd.to_numeric(weather[c], errors="coerce").astype("Int64")

    weather["hour_local"] = pd.to_datetime(
        dict(year=weather["year"], month=weather["month"], day=weather["day"], hour=weather["hour"]),
        errors="coerce"
    )

    # align dtype with agg.hour_local (timestamp[us][pyarrow])
    weather["hour_local"] = weather["hour_local"].astype("timestamp[us][pyarrow]")

    weather = weather.rename(columns={
        "temp":"temp_c","rhum":"humidity","prcp":"precip_mm",
        "wdir":"wind_direction","wspd":"wind_speed_kmh",
        "pres":"pressure_hpa","coco":"weather_condition"
    })[
        ["hour_local","temp_c","humidity","precip_mm",
         "wind_direction","wind_speed_kmh","pressure_hpa","weather_condition"]
    ]

    df_trips = (
        agg.merge(weather, on="hour_local", how="left")
           .merge(zones, on="PULocationID", how="left")
           .sort_values(["hour_local","PULocationID"])
    )

    print("Executed by Pandas")
    return df_trips

# %%
exec_method = "DUCKDB"
if exec_method == "DUCKDB":
    df_trips = executeWithDuckdb()
elif exec_method == "POLARS":
    df_trips = executeWithPolars()
else:
    df_trips = executeWithPandas()

display(df_trips.shape)
df_trips.head(3)
# Out:
# Executed by Pandas
# (77547, 19)
#             hour_local  PULocationID  trips  avg_fare  avg_tip  avg_total  \
# 0  2002-12-31 22:00:00           170      2       0.0      0.0        0.0
# 1  2009-01-01 00:00:00           138      1      50.6      0.0      68.29
# 2  2009-01-01 23:00:00           137      1       4.4      0.0        9.4
#
#    avg_distance  avg_trip_minutes  tip_pct  temp_c  humidity  precip_mm  \
# 0          0.63          6.033333      0.0    <NA>      <NA>       <NA>
# 1         10.88             48.85      0.0    <NA>      <NA>       <NA>
# 2          0.46               3.0      0.0    <NA>      <NA>       <NA>
#
#    wind_direction  wind_speed_kmh  pressure_hpa  weather_condition    Borough  \
# 0            <NA>            <NA>          <NA>               <NA>  Manhattan
# 1            <NA>            <NA>          <NA>               <NA>     Queens
# 2            <NA>            <NA>          <NA>               <NA>  Manhattan
#
#                 Zone service_zone
# 0        Murray Hill  Yellow Zone
# 1  LaGuardia Airport     Airports
# 2           Kips Bay  Yellow Zone

# %% [markdown]
# ## Check Table Info

# %%
print("DUPLICATE COUNT------------------------------------------------------")
print(f"df_trips: {df_trips.duplicated().sum()}")
print(f"df_zones: {df_zones.collect().to_pandas().duplicated().sum()}")
print(f"df_weather: {df_weather.collect().to_pandas().duplicated().sum()}")

print("INFO------------------------------------------------------")
print(f"df_trips: {df_trips.info()}\n\n\n")
print(f"df_zones: {df_zones.collect().to_pandas().info()}\n\n\n")
print(f"df_weather: {df_weather.collect().to_pandas().info()}\n\n\n")
# Out:
# DUPLICATE COUNT------------------------------------------------------
# df_trips: 0
# df_zones: 0
# df_weather: 0
# INFO------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77547 entries, 0 to 77546
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hour_local         77547 non-null  timestamp[us][pyarrow]
#  1   PULocationID       77547 non-null  Int64
#  2   trips              77547 non-null  int64[pyarrow]
#  3   avg_fare           77547 non-null  double[pyarrow]
#  4   avg_tip            77547 non-null  double[pyarrow]
#  5   avg_total          77547 non-null  double[pyarrow]
#  6   avg_distance       77547 non-null  double[pyarrow]
#  7   avg_trip_minutes   77547 non-null  double[pyarrow]
#  8   tip_pct            77547 non-null  double[pyarrow]
#  9   temp_c             77533 non-null  double[pyarrow]
#  10  humidity           77533 non-null  int64[pyarrow]
#  11  precip_mm          77533 non-null  double[pyarrow]
#  12  wind_direction     77533 non-null  int64[pyarrow]
#  13  wind_speed_kmh     77533 non-null  double[pyarrow]
#  14  pressure_hpa       77533 non-null  double[pyarrow]
#  15  weather_condition  77533 non-null  int64[pyarrow]
#  16  Borough            77547 non-null  string[pyarrow]
#  17  Zone               77547 non-null  string[pyarrow]
#  18  service_zone       77547 non-null  string[pyarrow]
# dtypes: Int64(1), double[pyarrow](10), int64[pyarrow](4), string[pyarrow](3), timestamp[us][pyarrow](1)
# memory usage: 13.0 MB
# df_trips: None
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          265 non-null    object
#  3   service_zone  265 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB
# df_zones: None
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         8784 non-null   int64
#  1   month        8784 non-null   int64
#  2   day          8784 non-null   int64
#  3   hour         8784 non-null   int64
#  4   temp         8784 non-null   float64
#  5   temp_source  8784 non-null   object
#  6   rhum         8784 non-null   int64
#  7   rhum_source  8784 non-null   object
#  8   prcp         8784 non-null   float64
#  9   prcp_source  8784 non-null   object
#  10  snwd         7820 non-null   float64
#  11  snwd_source  7820 non-null   object
#  12  wdir         8784 non-null   int64
#  13  wdir_source  8784 non-null   object
#  14  wspd         8784 non-null   float64
#  15  wspd_source  8784 non-null   object
#  16  wpgt         8784 non-null   float64
#  17  wpgt_source  8784 non-null   object
#  18  pres         8784 non-null   float64
#  19  pres_source  8784 non-null   object
#  20  tsun         8784 non-null   int64
#  21  tsun_source  8784 non-null   object
#  22  cldc         8783 non-null   float64
#  23  cldc_source  8784 non-null   object
#  24  coco         8784 non-null   int64
#  25  coco_source  8784 non-null   object
# dtypes: float64(7), int64(8), object(11)
# memory usage: 1.7+ MB
# df_weather: None

# %% [markdown]
# ## Drop Duplicate Rows

# %%
df_trips.drop_duplicates(inplace=True)
df_trips.shape
# Out:
# (77547, 19)

# %% [markdown]
# ## Check Missing Values

# %%
df_trips.isna().mean().round(4) * 100
# Out:
# hour_local           0.00
# PULocationID         0.00
# trips                0.00
# avg_fare             0.00
# avg_tip              0.00
# avg_total            0.00
# avg_distance         0.00
# avg_trip_minutes     0.00
# tip_pct              0.00
# temp_c               0.02
# humidity             0.02
# precip_mm            0.02
# wind_direction       0.02
# wind_speed_kmh       0.02
# pressure_hpa         0.02
# weather_condition    0.02
# Borough              0.00
# Zone                 0.00
# service_zone         0.00
# dtype: float64

# %%
# Quick sanity checks (optional)
# Confirm missingness isn’t clustered (i.e., not all at specific hours/locations):
# If it’s evenly spread, you’re good. If it clusters, consider an as-of join or light interpolation later.
na = df_trips["temp_c"].isna()
print(f"Mean: {na.mean()}\n\n")  # ~0.02
print(f"{df_trips.loc[na, "hour_local"].dt.hour.value_counts(normalize=True).head()}\n\n")
print(df_trips.loc[na, "PULocationID"].value_counts().head())
# Out:
# Mean: 0.00018053567513894798
#
#
# hour_local
# 23    0.857143
# 22    0.071429
# 0     0.071429
# Name: proportion, dtype: double[pyarrow]
#
#
# PULocationID
# 138    2
# 170    1
# 137    1
# 237    1
# 68     1
# Name: count, dtype: Int64

# %% [markdown]
# * **Overall missing rate:** `0.0001805` ⇒ **0.018%** (6 rows out of ~33k).
# * **When?** Mostly at **23:00** (late night), with a few at 22:00 and 00:00.
# * **Where?** A handful of zones (PULocationID 138 twice; 170/137/237/68 once each).
#
# That’s tiny and **localized at day boundaries**, which usually points to a *join-gap* (weather table missing the last hour of some days, or a 1-hour misalignment). What to do?
#
# 1. **Do nothing** → leave as NA. At 0.018%, this is totally acceptable for EDA, BI, and most tree models.
# 2. **Patch via nearest-hour join** (±1h tolerance) to catch those boundary hours.
# 3. **Drop those 6 rows** if you need fully numeric data right now and don’t want to impute.
#
# If weather is missing `23:00` for those dates, that’s it. If not, check timezone alignment (ensure both trips and weather are in the **same local tz** before truncation).
#
# So with only **6 rows** affected, you can safely **leave them as NA** or apply a simple **nearest-hour join** to clean them up.

# %%
# Since tip_pct has almost 64% missing values - dropping it. <5% missing we drop rows, >10% missing we impute, >=50% we drop column.
df_trips = df_trips.drop(columns=["tip_pct"])

# %% [markdown]
# ## Handle Numeric Columns (Optional)

# %%
def convert_to_numeric(df_trips):
    num_cols = [3, 4, 5, 17, 18]
    c = df_trips.columns[num_cols]
    
    # 1) Trim only where values are strings (works with mixed-type object columns)
    df_trips[c] = df_trips[c].map(lambda x: x.strip() if isinstance(x, str) else x)
    
    # 2) Remove common non-numeric artifacts and normalize negatives in parentheses
    df_trips[c] = (df_trips[c]
        .replace({'\u00A0': ' ', ',': '', r'\$': '', '%': ''}, regex=True)  # nbsp, commas, $, %
        .replace(r'^\((.*)\)$', r'-\1', regex=True)                         # (123) -> -123
        .replace({'': pd.NA, 'nan': pd.NA, '—': pd.NA, '–': pd.NA})         # blanks/dashes -> NA
    )
    
    # 3) Convert to numeric; anything unparseable becomes NaN/<NA>
    df_trips[c] = df_trips[c].apply(pd.to_numeric, errors='coerce')
    
    # 4) Use pandas' nullable dtypes so columns don't fall back to object
    df_trips[c] = df_trips[c].convert_dtypes()
    
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77547 entries, 0 to 77546
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hour_local         77547 non-null  timestamp[us][pyarrow]
#  1   PULocationID       77547 non-null  Int64
#  2   trips              77547 non-null  int64[pyarrow]
#  3   avg_fare           77547 non-null  double[pyarrow]
#  4   avg_tip            77547 non-null  double[pyarrow]
#  5   avg_total          77547 non-null  double[pyarrow]
#  6   avg_distance       77547 non-null  double[pyarrow]
#  7   avg_trip_minutes   77547 non-null  double[pyarrow]
#  8   temp_c             77533 non-null  double[pyarrow]
#  9   humidity           77533 non-null  int64[pyarrow]
#  10  precip_mm          77533 non-null  double[pyarrow]
#  11  wind_direction     77533 non-null  int64[pyarrow]
#  12  wind_speed_kmh     77533 non-null  double[pyarrow]
#  13  pressure_hpa       77533 non-null  double[pyarrow]
#  14  weather_condition  77533 non-null  int64[pyarrow]
#  15  Borough            77547 non-null  string[pyarrow]
#  16  Zone               77547 non-null  string[pyarrow]
#  17  service_zone       77547 non-null  string[pyarrow]
# dtypes: Int64(1), double[pyarrow](9), int64[pyarrow](4), string[pyarrow](3), timestamp[us][pyarrow](1)
# memory usage: 12.4 MB

# %%
df_trips.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['PULocationID',
#  'trips',
#  'avg_fare',
#  'avg_tip',
#  'avg_total',
#  'avg_distance',
#  'avg_trip_minutes',
#  'temp_c',
#  'humidity',
#  'precip_mm',
#  'wind_direction',
#  'wind_speed_kmh',
#  'pressure_hpa',
#  'weather_condition']

# %% [markdown]
# ## Handle Date Time Columns (Optional)

# %%
def convert_to_datetime(df_trips):
    date_cols = [1, 2]
    c = df_trips.columns[date_cols]
    
    df_trips[c] = df_trips[c].apply(lambda c : c.dt.tz_convert('America/New_York'))  # or .to_datetime(c, errors="coerce", utc=True)
    
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77547 entries, 0 to 77546
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hour_local         77547 non-null  timestamp[us][pyarrow]
#  1   PULocationID       77547 non-null  Int64
#  2   trips              77547 non-null  int64[pyarrow]
#  3   avg_fare           77547 non-null  double[pyarrow]
#  4   avg_tip            77547 non-null  double[pyarrow]
#  5   avg_total          77547 non-null  double[pyarrow]
#  6   avg_distance       77547 non-null  double[pyarrow]
#  7   avg_trip_minutes   77547 non-null  double[pyarrow]
#  8   temp_c             77533 non-null  double[pyarrow]
#  9   humidity           77533 non-null  int64[pyarrow]
#  10  precip_mm          77533 non-null  double[pyarrow]
#  11  wind_direction     77533 non-null  int64[pyarrow]
#  12  wind_speed_kmh     77533 non-null  double[pyarrow]
#  13  pressure_hpa       77533 non-null  double[pyarrow]
#  14  weather_condition  77533 non-null  int64[pyarrow]
#  15  Borough            77547 non-null  string[pyarrow]
#  16  Zone               77547 non-null  string[pyarrow]
#  17  service_zone       77547 non-null  string[pyarrow]
# dtypes: Int64(1), double[pyarrow](9), int64[pyarrow](4), string[pyarrow](3), timestamp[us][pyarrow](1)
# memory usage: 12.4 MB

# %%
df_trips.select_dtypes(include=['datetime', 'datetimetz']).columns.tolist()
# Out:
# ['hour_local']

# %% [markdown]
# ## Handle String Columns (Optional)

# %%
df_trips.head()
# Out:
#             hour_local  PULocationID  trips  avg_fare  avg_tip  avg_total  \
# 0  2002-12-31 22:00:00           170      2       0.0      0.0        0.0
# 1  2009-01-01 00:00:00           138      1      50.6      0.0      68.29
# 2  2009-01-01 23:00:00           137      1       4.4      0.0        9.4
# 3  2009-01-01 23:00:00           237      1      45.0      0.0       50.0
# 4  2023-12-31 23:00:00            68      1      10.7     3.14      18.84
#
#    avg_distance  avg_trip_minutes  temp_c  humidity  precip_mm  \
# 0          0.63          6.033333    <NA>      <NA>       <NA>
# 1         10.88             48.85    <NA>      <NA>       <NA>
# 2          0.46               3.0    <NA>      <NA>       <NA>
# 3         10.99              31.0    <NA>      <NA>       <NA>
# 4          1.44              9.65    <NA>      <NA>       <NA>
#
#    wind_direction  wind_speed_kmh  pressure_hpa  weather_condition    Borough  \
# 0            <NA>            <NA>          <NA>               <NA>  Manhattan
# 1            <NA>            <NA>          <NA>               <NA>     Queens
# 2            <NA>            <NA>          <NA>               <NA>  Manhattan
# 3            <NA>            <NA>          <NA>               <NA>  Manhattan
# 4            <NA>            <NA>          <NA>               <NA>  Manhattan
#
#                     Zone service_zone
# 0            Murray Hill  Yellow Zone
# 1      LaGuardia Airport     Airports
# 2               Kips Bay  Yellow Zone
# 3  Upper East Side South  Yellow Zone
# 4           East Chelsea  Yellow Zone

# %%
c = df_trips.select_dtypes(include=['object']).columns

def norm(c):
    return (
    c.astype("string")               # keeps NA as <NA>, not "nan"
     .str.replace("—", "-", regex=False)
     .str.replace("–", "-", regex=False)
     .str.replace("\u00A0", " ", regex=False)
     .str.replace(r"\\N", "N", regex=True)
     .str.strip()
)

def convert_to_object(df_trips):
    df_trips[c] = df_trips[c].apply(norm)
    df_trips.info()

# %%
display(df_trips.select_dtypes(include=['object']).columns.tolist())
# Out:
# []

# %% [markdown]
# ## Export Data

# %%
# To ensure all methods give same size output
output = "CSV"

if output == "CSV":
    df_trips.to_csv(
        "datasets/trips_complete.csv",
        index=False,
        na_rep="",
        float_format="%.6f",
        date_format="%Y-%m-%d %H:%M:%S",
        lineterminator="\n"
    )
else:
    # requires: pip install pyarrow
    df_trips.to_parquet(
        "datasets/trips_complete.parquet",
        engine="pyarrow",
        index=False,
        compression="zstd",          # strong + fast reads
        compression_level=12         # ~near-max without hurting read speed
    )

print("Done")
# Out:
# Done
